# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd

# %%
x=["Apple","Kiwi","Sbreerry","Mango"]
y=[40,20,35,23]
plt.bar(x,y)
plt.show()

# %%
 x=["Apple","Kiwi","Sbreerry","Mango"]
y=[40,20,35,23]
plt.bar(x,y,color="red")
plt.show()

# %%
x=["Apple","Kiwi","Sbreerry","Mango"]
y=[40,20,35,23]
colors=["red","brown","hotpink","yellow"]
plt.bar(x,y,color=colors)
plt.show()

# %%
  x=["Apple","Kiwi","Sbreerry","Mango"]
y=[40,20,35,23]
colors=["red","brown","hotpink","yellow"]
plt.bar(x,y,color=colors,width=0.5)
plt.show()

# %%
  x=["Apple","Kiwi","Sbreerry","Mango"]
y=[40,20,35,23]
colors=["red","brown","hotpink","yellow"]
lables=["Apple","Kiwi","Sbreerry","Mango"]
plt.bar(x,y,color=colors,width=0.5,label=lables)
plt.legend()
plt.show()

# %%
x=["Apple","Kiwi","Sbreerry","Mango"]
y=[40,20,35,23]
colors=["red","brown","hotpink","yellow"]
plt.barh(x,y)
plt.show()

# %%
x=["Apple","Kiwi","Sbreerry","Mango"]
y=[40,20,35,23]
colors=["red","brown","hotpink","yellow"]
plt.barh(x,y,color=colors)
plt.show()

# %%
x=["Apple","Kiwi","Sbreerry","Mango"]
y=[40,20,35,23]
colors=["red","brown","hotpink","yellow"]
plt.barh(x,y,color=colors,height=0.5)
plt.show()

# %%
  x=["Apple","Kiwi","Sbreerry","Mango"]
y=[40,20,35,23]
colors=["red","brown","hotpink","yellow"]
lables=["Apple","Kiwi","Sbreerry","Mango"]
plt.barh(x,y,color=colors,height=0.5,label=lables)
plt.legend()
plt.show()
