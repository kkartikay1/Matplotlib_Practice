# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Example Of line plot without grid

# %%
x=np.array([80,85,90,95,100,105,110,115,120,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])
plt.title("Sports watch Data")
plt.xlabel("Average Pluse")
plt.ylabel("Calorie Burnage")
plt.plot(x,y)
# plt.grid(axis='x')
plt.show()

# %%
x=np.array([80,85,90,95,100,105,110,115,120,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])
plt.title("Sports watch Data")
plt.xlabel("Average Pluse")
plt.ylabel("Calorie Burnage")
plt.plot(x,y,marker="d",mfc="r",c="lime",mec="b")
# plt.grid(axis='x')
plt.show()

# %%
# Example Of line plot with grid

# %%
 x=np.array([80,85,90,95,100,105,110,115,120,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])
plt.title("Sports watch Data")
plt.xlabel("Average Pluse")
plt.ylabel("Calorie Burnage")
plt.plot(x,y,marker="d",mfc="r",c="lime",mec="b")
plt.grid()
plt.show()

# %%
x=np.array([80,85,90,95,100,105,110,115,120,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])
plt.title("Sports watch Data")
plt.xlabel("Average Pluse")
plt.ylabel("Calorie Burnage")
plt.plot(x,y,marker="d",mfc="r",c="lime",mec="b")
plt.grid(axis='x')
plt.show()

# %%
x=np.array([80,85,90,95,100,105,110,115,120,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])
plt.title("Sports watch Data")
plt.xlabel("Average Pluse")
plt.ylabel("Calorie Burnage")
plt.plot(x,y,marker="d",mfc="r",c="lime",mec="b")
plt.grid(axis='y')
plt.show()

# %%
x=np.array([80,85,90,95,100,105,110,115,120,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])
plt.title("Sports watch Data")
plt.xlabel("Average Pluse")
plt.ylabel("Calorie Burnage")
plt.plot(x,y,marker="d",mfc="r",c="lime",mec="b")
plt.grid(axis='both')
plt.show()

# %%
x=np.array([80,85,90,95,100,105,110,115,120,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])
plt.title("Sports watch Data")
plt.xlabel("Average Pluse")
plt.ylabel("Calorie Burnage")
plt.plot(x,y,marker="d",mfc="r",c="lime",mec="b")
plt.grid(axis='both',lw=5,ls="dotted",c="yellow")
plt.show()

# %%
x=np.array([80,85,90,95,100,105,110,115,120,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])
plt.title("Sports watch Data")
plt.xlabel("Average Pluse")
plt.ylabel("Calorie Burnage")
plt.plot(x,y,marker="d",mfc="r",c="lime",mec="b")
plt.grid(axis='both',lw=5,ls="solid",c="yellow")
plt.show()

# %%
x=np.array([80,85,90,95,100,105,110,115,120,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])
plt.title("Sports watch Data")
plt.xlabel("Average Pluse")
plt.ylabel("Calorie Burnage")
plt.plot(x,y,marker="d",mfc="r",c="lime",mec="b")
plt.grid(axis='both',lw=2,ls="dotted",c="yellow")
plt.show()

# %%
x=np.array([80,85,90,95,100,105,110,115,120,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])
plt.title("Sports watch Data")
plt.xlabel("Average Pluse")
plt.ylabel("Calorie Burnage")
plt.plot(x,y,marker="d",mfc="r",c="b",mec="b",lw=6)
plt.grid(axis='both',lw=2,ls="solid",c="hotpink")
plt.show()
